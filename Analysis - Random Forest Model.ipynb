# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("data/imputed_data.csv")
print(df.columns)
# Out:
# Index(['Name', 'Position', 'College', 'Round', 'Pick', 'Stat URL', 'Height',
#        'Weight', '40 Yard Dash', 'Bench Press', 'Vertical Jump', 'Broad Jump',
#        '3 Cone Drill', 'Shuttle', 'conf_abbr', 'games', 'seasons',
#        'tackles_solo', 'tackles_assists', 'tackles_total', 'tackles_loss',
#        'sacks', 'def_int', 'def_int_yds', 'def_int_td', 'pass_defended',
#        'fumbles_rec', 'fumbles_rec_yds', 'fumbles_rec_td', 'fumbles_forced',
#        'rec', 'rec_yds', 'rec_yds_per_rec', 'rec_td', 'rush_att', 'rush_yds',
#        'rush_yds_per_att', 'rush_td', 'scrim_att', 'scrim_yds',
#        'scrim_yds_per_att', 'scrim_td', 'Year'],
#       dtype='object')

# %%
df.loc[df.Round != 1, "Round"] = 0

# Dropping the columns which donot contribute in prediction
all_X = df.drop(["Name", "Round", "Pick", "College"], axis=1)
all_X = pd.get_dummies(all_X)

# Splitting testing and training sets
train_X = all_X[(all_X.Year != 2023)].drop(["Year"], axis=1)
test_X = all_X[all_X.Year == 2023].drop(["Year"], axis=1)
train_y = df[(df.Year != 2023)].Round
test_y = df[df.Year == 2023].Round

# %%
# Training the model using Random Forest

param = {
    'n_estimators': [100, 500, 1000]
}

# Initialize the Random Forest classifier
rf = RandomForestClassifier()

# Hypertuning parameters using 5-Fold Cross Validation method
clf = GridSearchCV(estimator=rf, param_grid=param, cv=5, scoring='accuracy')
clf.fit(train_X, train_y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'n_estimators': [100, 500, 1000]}, scoring='accuracy')

# %%
# Get the best parameters
best_params = clf.best_params_
print("Best Parameters:", best_params)

# Use the best estimator to make predictions
best_rf = clf.best_estimator_
# Out:
# Best Parameters: {'n_estimators': 100}

# %%
# Predicting the probabilities of Test set
preds = best_rf.predict_proba(test_X)
count = 1

# Ranking done according to the probability scores
for i in pd.DataFrame(preds).sort_values(by=1, ascending=False).index:
    print(str(count) + " " + str(df[df.Year==2023].reset_index().at[i, "Name"]))
    count += 1
# Out:
# 1 C.J. Stroud
# 2 Anthony Richardson
# 3 Bryce Young
# 4 Jakorian Bennett
# 5 Dante Stills
# 6 Christian Gonzalez
# 7 Blake Freeland
# 8 Deonte Banks
# 9 Will Anderson Jr.
# 10 DJ Turner
# 11 Marvin Mims
# 12 Isaiah McGuire
# 13 Emmanuel Forbes
# 14 Hendon Hooker
# 15 Nolan Smith
# 16 Jaren Hall
# 17 Darnell Wright
# 18 Riley Moss
# 19 Tyler Steen
# 20 Nick Hampton
# 21 Carter Warren
# 22 Ryan Hayes
# 23 Isaiah Foskey
# 24 Owen Pappoe
# 25 Dawand Jones
# 26 Josh Downs
# 27 Julius Brents
# 28 Lukas Van Ness
# 29 Byron Young
# 30 Quentin Johnston
# 31 Zacch Pickens
# 32 Carrington Valentine
# 142 Felix Anudike-Uzomah
# 143 Mekhi Blackmon
# 144 Stetson Bennett
# 145 Jordan Howden
# 146 Chase Brown
# 147 Tiyon Evans
# 148 Kaevon Merriweather
# 149 Ochaun Mathis
# 150 Cameron Mitchell
# 151 Michael Mayer
# 152 Jacob Copeland
# 153 Daniel Scott
# 154 Emil Ekiyor Jr.
# 155 Camerun Peoples
# 156 Ivan Pace Jr.
# 157 Sam LaPorta
# 158 Rashad Torrence II
# 159 Tyler Lacy
# 160 Trey Dean III
# 161 Noah Sewell
# 162 Calijah Kancey
# 163 Antonio Johnson
# 164 Bryce Ford-Wheaton
# 165 Henry To'oTo'o
# 166 Tyrus Wheat
# 167 O'Cyrus Torrence
# 168 Ikenna Enechukwu
# 169 Luke Musgrave
# 170 Demario Douglas
# 171 Grant DuBose
# 172 Devon Achane
# 173 Nic Jones
# 174 Tuli Tuipulotu
# 175 SaRodorick Thompson
# 176 Ronnie Bell
# 177 Broderick Jones
# 178 Cedric Tillman
# 179 Will Levis
# 180 Xavier Hutchinson
# 181 Nick Broeker
# 182 Cameron Young
# 183 Alex Ward
# 184 Luke Wypler
# 185 Daiyan Henley
# 186 Christopher Smith
# 187 JL Skinner
# 188 Ricky Stromberg
# 189 Alex Austin
# 190 Luke Schoonmaker
# 191 Davis Allen
# 192 Chad Ryland
# 193 MJ Anderson
# 194 Adam Korsak
# 195 Noah Taylor
# 196 Lance Boykin
# 197 Ronnie Hickman
# 198 Garrett Williams
# 199 Keondre Coburn
# 200 Anthony Johnson
# 201 Jake Haener
# 202 Andrew Vorhees
# 203 Antoine Green
# 204 Tyreque Jones
# 205 Dorian Williams
# 206 Cameron Latu
# 207 Josh Whyle
# 208 Jake Moody
# 209 Zach Evans
# 210 BJ Ojulari
# 211 Gervarrius Owens
# 212 Mekhi Garner
# 213 Evan Hull
# 214 Jahmyr Gibbs
# 215 Alex Forsyth
# 216 Payne Durham
# 217 Christopher Dunn
# 218 Ji'Ayir Brown
# 219 Jack Podlesny
# 220 Clark Phillips III
# 221 Siaki Ika
# 222 Kearis Jackson
# 223 B.T. Potter
# 224 Kayshon Boutte
# 225 Jake Bobo
# 226 Malik Knowles
# 227 Keeanu Benton
# 228 Sean Tucker
# 229 Jayden Reed
# 230 SirVocea Dennis
# 231 Dalton Wagner
# 232 Travis Vokolek
# 233 Jalen Wayne
# 234 Mitchell Tinsley
# 235 Tre Tucker
# 236 Dalton Kincaid
# 237 Jadon Haselwood
# 238 Puka Nacua
# 239 Max Duggan
# 240 Jovaughn Gwyn
# 241 Brenton Strange
# 242 Malik Heath
# 243 Charlie Jones
# 244 Brenton Cox
# 245 Kenny McIntosh
# 246 Travis Dye
# 247 Anders Carlson
# 248 Jalen Graham
# 249 DeMarvion Overshown
# 250 Deneric Prince
# 251 Micah Baskerville
# 252 Alan Ali
# 253 Dee Winters
# 254 Devon Witherspoon
# 255 Brayden Willis
# 256 Arquon Bush
# 257 Zach Charbonnet
# 258 DJ Dale
# 259 Derius Davis
# 260 Blake Whiteheart
# 261 Bryce Baringer
# 262 Henry Bainivalu
# 263 Jordan Addison
# 264 Michael Wilson
# 265 Leonard Taylor
# 266 Eric Gray
# 267 Ventrell Miller
# 268 Tavion Thomas
# 269 Juice Scruggs
# 270 John Michael Schmitz
# 271 Kyle Patterson
# 272 Jarrett Patterson
# 273 Elijah Higgins
# 274 Israel Abanikanda
# 275 Kendre Miller
# 276 Cam Jones
# 277 Roschon Johnson
# 278 Michael Turk
# 279 Dontay Demus Jr.
# 280 Brad Robbins
# 281 Brandon Joseph
# 282 Jake Andrews
# 283 Justin Shorter
# 284 Joseph Ngata

# %%
from sklearn.metrics import accuracy_score, roc_auc_score
import numpy as np

# Convert predicted probabilities to binary predictions based on a threshold (e.g., 0.5)
predicted_labels = (preds[:, 1] > 0.5).astype(int)

# Calculate evaluation metrics - Accuracy and ROC_Score
accuracy = accuracy_score(test_y, predicted_labels)
roc_auc = roc_auc_score(test_y, preds[:, 1])

# %%
# Evaluation for ranking metrics
# Sort the predictions based on probability scores
sorted_indices = np.argsort(-preds[:, 1])

# Calculate Mean Reciprocal Rank (MRR)
mrr = 0
for idx, i in enumerate(sorted_indices):
    if test_y.iloc[i] == 1:  # Use iloc to access test_y by index
        mrr = 1 / (idx + 1)
        break

# Calculate Mean Average Precision (MAP)
num_relevant = sum(test_y)
ap = 0
for idx, i in enumerate(sorted_indices):
    if test_y.iloc[i] == 1:
        ap += sum(test_y.iloc[:idx + 1]) / (idx + 1)
map_score = ap / num_relevant

# Calculate Normalized Discounted Cumulative Gain (NDCG) at k=10
k = 10
dcg = 0
idcg = sum(1 / np.log2(np.arange(2, k + 2)))
for idx, i in enumerate(sorted_indices[:k]):
    if test_y.iloc[i] == 1:
        dcg += 1 / np.log2(idx + 2)
ndcg = dcg / idcg

# Calculate Precision at k (P@k) and Recall at k (R@k) at k=10
tp_at_k = sum(test_y.iloc[sorted_indices[:k]])
precision_at_k = tp_at_k / k
recall_at_k = tp_at_k / num_relevant


print("Accuracy:", accuracy)
print("ROC AUC Score:", roc_auc)
print("Mean Reciprocal Rank (MRR):", mrr)
print("Mean Average Precision (MAP):", map_score)
print("Normalized Discounted Cumulative Gain (NDCG) at k=10:", ndcg)
print("Precision at k (P@k) at k=10:", precision_at_k)
print("Recall at k (R@k) at k=10:", recall_at_k)
# Out:
# Accuracy: 0.897887323943662
# ROC AUC Score: 0.7393509127789046
# Mean Reciprocal Rank (MRR): 1.0
# Mean Average Precision (MAP): 0.10529849177177532
# Normalized Discounted Cumulative Gain (NDCG) at k=10: 0.6168295842361274
# Precision at k (P@k) at k=10: 0.5
# Recall at k (R@k) at k=10: 0.1724137931034483
