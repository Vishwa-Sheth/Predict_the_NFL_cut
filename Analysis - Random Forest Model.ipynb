# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("data/imputed_data.csv")
print(df.columns)
# Out:
# Index(['Name', 'Position', 'College', 'Round', 'Pick', 'Stat URL', 'Height',
#        'Weight', '40 Yard Dash', 'Bench Press', 'Vertical Jump', 'Broad Jump',
#        '3 Cone Drill', 'Shuttle', 'conf_abbr', 'games', 'seasons',
#        'tackles_solo', 'tackles_assists', 'tackles_total', 'tackles_loss',
#        'sacks', 'def_int', 'def_int_yds', 'def_int_td', 'pass_defended',
#        'fumbles_rec', 'fumbles_rec_yds', 'fumbles_rec_td', 'fumbles_forced',
#        'rec', 'rec_yds', 'rec_yds_per_rec', 'rec_td', 'rush_att', 'rush_yds',
#        'rush_yds_per_att', 'rush_td', 'scrim_att', 'scrim_yds',
#        'scrim_yds_per_att', 'scrim_td', 'Year'],
#       dtype='object')

# %%
df.loc[df.Round != 1, "Round"] = 0

# Dropping the columns which donot contribute in prediction
all_X = df.drop(["Name", "Round", "Pick", "College"], axis=1)
all_X = pd.get_dummies(all_X)

# Splitting testing and training sets
train_X = all_X[(all_X.Year != 2023)].drop(["Year"], axis=1)
test_X = all_X[all_X.Year == 2023].drop(["Year"], axis=1)
train_y = df[(df.Year != 2023)].Round
test_y = df[df.Year == 2023].Round

# Training the model using Random Forest
clf = RandomForestClassifier(n_estimators=1000)
clf.fit(train_X, train_y)
# Out:
# RandomForestClassifier(n_estimators=1000)

# %%
# Predicting the probabilities of Test set
preds = clf.predict_proba(test_X)
count = 1

# Ranking done according to the probability scores
for i in pd.DataFrame(preds).sort_values(by=1, ascending=False).index:
    print(str(count) + " " + str(df[df.Year==2023].reset_index().at[i, "Name"]))
    count += 1
# Out:
# 1 Bryce Young
# 2 C.J. Stroud
# 3 Anthony Richardson
# 4 Jakorian Bennett
# 5 DJ Turner
# 6 Christian Gonzalez
# 7 Byron Young
# 8 Will Anderson Jr.
# 9 Jaren Hall
# 10 Darnell Wright
# 11 Emmanuel Forbes
# 12 Hendon Hooker
# 13 Marvin Mims
# 14 Blake Freeland
# 15 Deonte Banks
# 16 Dante Stills
# 17 Tyler Steen
# 18 Carrington Valentine
# 19 Dawand Jones
# 20 Nolan Smith
# 21 Cam Smith
# 22 Kelee Ringo
# 23 Trenton Simpson
# 24 Adetomiwa Adebawore
# 25 Isaiah Foskey
# 26 Ryan Hayes
# 27 Julius Brents
# 28 Carter Warren
# 29 Jalin Hyatt
# 30 Tre'Vius Hodges-Tomlinson
# 31 YaYa Diaby
# 32 Yasir Abdullah
# 33 Quentin Johnston
# 34 Lukas Van Ness
# 35 Joe Tippmann
# 36 Richard Gouraige
# 37 Owen Pappoe
# 38 Jalen Redmond
# 39 Rejzohn Wright
# 40 Nick Hampton
# 41 Nathaniel Dell
# 42 Thomas Incoom
# 43 A.T. Perry
# 44 Josh Downs
# 149 Cedric Tillman
# 150 Dylan Horton
# 151 Jake Moody
# 152 Jaylon Jones
# 153 Daiyan Henley
# 154 Tyrus Wheat
# 155 Chase Brown
# 156 Gervarrius Owens
# 157 Bryan Bresee
# 158 Ronnie Bell
# 159 Mekhi Blackmon
# 160 Isaiah Moore
# 161 Jordan McFadden
# 162 Luke Schoonmaker
# 163 Antoine Green
# 164 Ochaun Mathis
# 165 Jaxson Kirkland
# 166 Nic Jones
# 167 Ronnie Hickman
# 168 MJ Anderson
# 169 Tyjae Spears
# 170 DeMarcco Hellams
# 171 Broderick Jones
# 172 Noah Taylor
# 173 Devon Achane
# 174 Lonnie Phelps
# 175 Will Mallory
# 176 Michael Wilson
# 177 Malik Knowles
# 178 John Michael Schmitz
# 179 Noah Sewell
# 180 Dee Winters
# 181 PJ Mustipher
# 182 Garrett Williams
# 183 Jovaughn Gwyn
# 184 Mekhi Garner
# 185 Ricky Stromberg
# 186 Grant DuBose
# 187 Jake Bobo
# 188 Will Levis
# 189 Davis Allen
# 190 Shaka Heyward
# 191 Cameron Mitchell
# 192 JL Skinner
# 193 Sam LaPorta
# 194 Nick Broeker
# 195 Evan Hull
# 196 Travis Dye
# 197 Trey Dean III
# 198 Dalton Wagner
# 199 Juice Scruggs
# 200 Byron Young
# 201 Stetson Bennett
# 202 Andrew Vorhees
# 203 Luke Wypler
# 204 Keondre Coburn
# 205 Jayden Reed
# 206 Terell Smith
# 207 Zach Charbonnet
# 208 Emil Ekiyor Jr.
# 209 Alex Ward
# 210 Jammie Robinson
# 211 Mitchell Tinsley
# 212 Jaray Jenkins
# 213 Kaevon Merriweather
# 214 Jahmyr Gibbs
# 215 Siaki Ika
# 216 Charlie Jones
# 217 Derius Davis
# 218 Brandon Joseph
# 219 Ivan Pace Jr.
# 220 Jake Haener
# 221 Sean Tucker
# 222 SaRodorick Thompson
# 223 Dalton Kincaid
# 224 SirVocea Dennis
# 225 Zach Evans
# 226 Anthony Johnson
# 227 Deneric Prince
# 228 Alex Austin
# 229 Payne Durham
# 230 DJ Dale
# 231 Jordan Howden
# 232 Josh Whyle
# 233 Christopher Dunn
# 234 Tre Tucker
# 235 Alex Forsyth
# 236 Arquon Bush
# 237 Luke Musgrave
# 238 Dorian Williams
# 239 Puka Nacua
# 240 Elijah Higgins
# 241 Leonard Taylor
# 242 Anders Carlson
# 243 Kendre Miller
# 244 DeMarvion Overshown
# 245 Tank Bigsby
# 246 Christopher Smith
# 247 Jordan Addison
# 248 Brenton Strange
# 249 Devon Witherspoon
# 250 Alan Ali
# 251 Justin Shorter
# 252 Malik Heath
# 253 Camerun Peoples
# 254 Jarrett Patterson
# 255 Jadon Haselwood
# 256 Keeanu Benton
# 257 Micah Baskerville
# 258 Ventrell Miller
# 259 Jack Podlesny
# 260 Adam Korsak
# 261 Roschon Johnson
# 262 Bryce Baringer
# 263 Israel Abanikanda
# 264 Kenny McIntosh
# 265 Henry Bainivalu
# 266 Dontay Demus Jr.
# 267 Jalen Wayne
# 268 Kyle Patterson
# 269 Joseph Ngata
# 270 Tavion Thomas
# 271 Max Duggan
# 272 Lance Boykin
# 273 Eric Gray
# 274 Blake Whiteheart
# 275 Jake Andrews
# 276 Chad Ryland
# 277 Travis Vokolek
# 278 B.T. Potter
# 279 Brayden Willis
# 280 Brad Robbins
# 281 Michael Turk
# 282 Jalen Graham
# 283 Cam Jones
# 284 Cameron Latu

# %%
from sklearn.metrics import accuracy_score, roc_auc_score
import numpy as np

# Convert predicted probabilities to binary predictions based on a threshold (e.g., 0.5)
predicted_labels = (preds[:, 1] > 0.5).astype(int)

# Calculate evaluation metrics - Accuracy and ROC_Score
accuracy = accuracy_score(test_y, predicted_labels)
roc_auc = roc_auc_score(test_y, preds[:, 1])

# %%
# Evaluation for ranking metrics
# Sort the predictions based on probability scores
sorted_indices = np.argsort(-preds[:, 1])

# Calculate Mean Reciprocal Rank (MRR)
mrr = 0
for idx, i in enumerate(sorted_indices):
    if test_y.iloc[i] == 1:  # Use iloc to access test_y by index
        mrr = 1 / (idx + 1)
        break

# Calculate Mean Average Precision (MAP)
num_relevant = sum(test_y)
ap = 0
for idx, i in enumerate(sorted_indices):
    if test_y.iloc[i] == 1:
        ap += sum(test_y.iloc[:idx + 1]) / (idx + 1)
map_score = ap / num_relevant

# Calculate Normalized Discounted Cumulative Gain (NDCG) at k=10
k = 10
dcg = 0
idcg = sum(1 / np.log2(np.arange(2, k + 2)))
for idx, i in enumerate(sorted_indices[:k]):
    if test_y.iloc[i] == 1:
        dcg += 1 / np.log2(idx + 2)
ndcg = dcg / idcg

# Calculate Precision at k (P@k) and Recall at k (R@k) at k=10
tp_at_k = sum(test_y.iloc[sorted_indices[:k]])
precision_at_k = tp_at_k / k
recall_at_k = tp_at_k / num_relevant


print("Accuracy:", accuracy)
print("ROC AUC Score:", roc_auc)
print("Mean Reciprocal Rank (MRR):", mrr)
print("Mean Average Precision (MAP):", map_score)
print("Normalized Discounted Cumulative Gain (NDCG) at k=10:", ndcg)
print("Precision at k (P@k) at k=10:", precision_at_k)
print("Recall at k (R@k) at k=10:", recall_at_k)
# Out:
# Accuracy: 0.897887323943662
# ROC AUC Score: 0.7208248816768086
# Mean Reciprocal Rank (MRR): 1.0
# Mean Average Precision (MAP): 0.10441733328653606
# Normalized Discounted Cumulative Gain (NDCG) at k=10: 0.6804503724350792
# Precision at k (P@k) at k=10: 0.6
# Recall at k (R@k) at k=10: 0.20689655172413793
